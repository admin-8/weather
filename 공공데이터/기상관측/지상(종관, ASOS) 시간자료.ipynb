# %%
import warnings
import pandas as pd
warnings.filterwarnings('ignore')
pd.set_option('display.max_row', 10000000)
pd.set_option('display.max_columns', 10000000)

# %%
import requests

def get_request_query(url, operation, params, serviceKey):
    import urllib.parse as urlparse
    params = urlparse.urlencode(params)
    request_query = []

    f_url = url + "/" + operation + "?" + params + "&" + "serviceKey" + "=" + serviceKey
    f_url.encode('utf-8')
    request_query.append(f_url)
        
    return request_query

# %%
URL = "http://apis.data.go.kr/1360000/AwsYearlyInfoService"
API_KEY = "0VPHiLnleAB93gjILfRfKRQcBuFBbb9XArHRML7HRiBSrkUV4GZxTwOsm%2Fm%2FloyDIFYPsLSoNQFg2j%2FAfxNfnQ%3D%3D"
OPERATION = "getYearSumry"
PARAMS = {'numOfRows':'999', 'pageNo':'1', 'dataType':'XML', 'year':'2019', 'month':'01'}
#PARAMS_KEY = ['numOfRows', 'pageNo', 'dataType','year']
#PARAMS_VAL = ['999','1','JSON','2019']
#PARAMS = dict(zip(PARAMS_KEY, PARAMS_VAL))
print(PARAMS)
#CODE = ['01'] # , '112', '119','133', '159', '232'
#CODENAME = 'month'
# Out:
# {'numOfRows': '999', 'pageNo': '1', 'dataType': 'XML', 'year': '2019', 'month': '01'}

# %%
request_query = get_request_query(URL, OPERATION,PARAMS, API_KEY)
for i in (request_query):
    print(i)
    response = requests.get(url=i)
    #print(response.text)
# Out:
# http://apis.data.go.kr/1360000/AwsYearlyInfoService/getYearSumry?numOfRows=999&pageNo=1&dataType=XML&year=2019&month=01&serviceKey=0VPHiLnleAB93gjILfRfKRQcBuFBbb9XArHRML7HRiBSrkUV4GZxTwOsm%2Fm%2FloyDIFYPsLSoNQFg2j%2FAfxNfnQ%3D%3D

# %%
print(response.text)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <response><header><resultCode>00</resultCode><resultMsg>NORMAL_SERVICE</resultMsg></header><body><dataType>XML</dataType><items><item><year>
#  <info>
#   <stnId>96</stnId>
#   <stnKo>독도</stnKo>
#   <mm><![CDATA[null]]></mm>
#   <taDay><![CDATA[145]]></taDay>
#   <taMaxAvg><![CDATA[165]]></taMaxAvg>
#   <taMax><![CDATA[300]]></taMax>
#   <taMaxDay><![CDATA[08/02]]></taMaxDay>
#   <taMinAvg><![CDATA[128]]></taMinAvg>
#   <taMin><![CDATA[-14]]></taMin>
#   <taMinDay><![CDATA[01/26]]></taMinDay>
#   <wsDay><![CDATA[38]]></wsDay>
#   <wsInsMax><![CDATA[323]]></wsInsMax>
#   <wdInsMax><![CDATA[WSW]]></wdInsMax>
#   <wsInsMaxTm><![CDATA[10/03]]></wsInsMaxTm>
#   <rnDay><![CDATA[4790]]></rnDay>
#   <rn1hrMax><![CDATA[230]]></rn1hrMax>
#   <rn1hrMaxTm><![CDATA[11/15]]></rn1hrMaxTm>
#  </info>
#  <info>
#   <stnId>116</stnId>
#   <stnKo>관악(레)</stnKo>
#   <mm><![CDATA[null]]></mm>
#   <taDay><![CDATA[97]]></taDay>
# ...

# %%
type(json_)
print(json_)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <response><header><resultCode>00</resultCode><resultMsg>NORMAL_SERVICE</resultMsg></header><body><dataType>XML</dataType><items><item><year>
#  <info>
#   <stnId>96</stnId>
#   <stnKo>독도</stnKo>
#   <mm><![CDATA[null]]></mm>
#   <taDay><![CDATA[145]]></taDay>
#   <taMaxAvg><![CDATA[165]]></taMaxAvg>
#   <taMax><![CDATA[300]]></taMax>
#   <taMaxDay><![CDATA[08/02]]></taMaxDay>
#   <taMinAvg><![CDATA[128]]></taMinAvg>
#   <taMin><![CDATA[-14]]></taMin>
#   <taMinDay><![CDATA[01/26]]></taMinDay>
#   <wsDay><![CDATA[38]]></wsDay>
#   <wsInsMax><![CDATA[323]]></wsInsMax>
#   <wdInsMax><![CDATA[WSW]]></wdInsMax>
#   <wsInsMaxTm><![CDATA[10/03]]></wsInsMaxTm>
#   <rnDay><![CDATA[4790]]></rnDay>
#   <rn1hrMax><![CDATA[230]]></rn1hrMax>
#   <rn1hrMaxTm><![CDATA[11/15]]></rn1hrMaxTm>
#  </info>
#  <info>
#   <stnId>116</stnId>
#   <stnKo>관악(레)</stnKo>
#   <mm><![CDATA[null]]></mm>
#   <taDay><![CDATA[97]]></taDay>
# ...

# %%
import json

# %%
json_object = json.loads(json_)
json_object
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-16-7d16e4e73b7e> in <module>
# ----> 1 json_object = json.loads(json_)
#       2 json_object
#
# ~\anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
# ...

# %%
wq = [json_['response']['body']['items']['item']['year']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-c9c2ce9fea67> in <module>
# ----> 1 wq = [json_['response']['body']['items']['item']['year']]
#
# TypeError: string indices must be integers

# %%
#print(request_query)
type(json_)
ja = json.dumps(json_)
#print(ja)
print(type(ja))
# Out:
# <class 'str'>

# %%
from ast import literal_eval
URL = str(input("URL 주소를 입력하시오: "))
API_KEY = str(input("인증키를 입력하시오: "))
OPERATION = str(input("상세기능명을 입력하시오(영문): "))
    #NUMOFROWS = str(input("한 페이지에 노출할 결과 수를 입력하시오: "))
    #PAGENO = str(input("페이지 번호를 입력하시오: "))
    #DATATYPE = str(input("데이터 타입을 입력하시오: "))
PARAMS_KEY = list(input("항목명을 공백으로 구분하여 입력하시오: ").split())
PARAMS_VALUE = list(input("항목값을 공백으로 구분하여 입력하시오: ").split())
PARAMS_STR = str(dict(zip(PARAMS_KEY, PARAMS_VALUE)))
PARAMS = literal_eval(PARAMS_STR)
CODENAME = str(input('지점번호, 지역코드와 관련된 항목명을 입력하시오: '))
CODE = list(input('지점번호, 지역코드를 입력하시오: ').split())
# Out:
# URL 주소를 입력하시오: http://apis.data.go.kr/1360000/AsosDalyInfoService
# 인증키를 입력하시오: 0VPHiLnleAB93gjILfRfKRQcBuFBbb9XArHRML7HRiBSrkUV4GZxTwOsm%2Fm%2FloyDIFYPsLSoNQFg2j%2FAfxNfnQ%3D%3D
# 상세기능명을 입력하시오(영문): getWthrDataList
# 항목명을 공백으로 구분하여 입력하시오: numOfRows pageNo dataType dataCd dateCd startDt endDt
# 항목값을 공백으로 구분하여 입력하시오: 999 1 JSON ASOS DAY 20200101 20200701
# 지점번호, 지역코드와 관련된 항목명을 입력하시오: stnIds
# 지점번호, 지역코드를 입력하시오: 108

# %%
print(type(URL))
print(type(API_KEY))
print(type(OPERATION))
print(type(PARAMS))
#print(type(CODENAME))
print(type(CODE))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'dict'>
# <class 'list'>

# %%
print(URL)
# Out:
# http://apis.data.go.kr/1360000/AsosDalyInfoService

# %%
json_ = json_.encode('utf-8')

# %%
import pandas as pd
from pandas.io.json import json_normalize

body = [json_object['response']['body']['items']]
body
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d6a2f54f0701> in <module>
#       2 from pandas.io.json import json_normalize
#       3
# ----> 4 body = [json_object['response']['body']['items']]
#       5 body
#
# NameError: name 'json_object' is not defined

# %%
a = json_normalize(json_object['response']['body']['items']['item'])
a
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#   stnId          tm  avgTa  minTa  minTaHrmt  maxTa  maxTaHrmt  mi10MaxRnHrmt  \
# 0   108  2020-01-01   -2.2   -6.5          1    0.3       1457              0
# 1   108  2020-01-02    1.0   -0.7          1    3.8       1500              0
# 2   108  2020-01-03   -0.1   -3.4        807    4.6       1547              0
# 3   108  2020-01-04    1.2   -2.8        512    6.1       1450              0
# 4   108  2020-01-05    1.3   -3.2        821    6.6       1453              0
# 5   108  2020-01-06    3.1    0.6         53    4.6       1158              0
# 6   108  2020-01-07    6.3    4.2          1    7.7       2350              0
# 7   108  2020-01-08    2.4   -0.4       2336    8.9         47              0
# ...

# %%
AsosHourlyInfoService_describe = a.describe()

AsosHourlyInfoService_describe.to_csv('data/AsosHourlyInfoService_describe.csv', index=True, encoding='cp949')

# %%
AsosHourlyInfoService_info = a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 38 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tm          999 non-null    object
#  1   rnum        999 non-null    object
#  2   stnId       999 non-null    object
#  3   ta          999 non-null    float64
#  4   taQcflg     999 non-null    object
#  5   rn          999 non-null    float64
#  6   rnQcflg     999 non-null    object
#  7   ws          999 non-null    float64
#  8   wsQcflg     999 non-null    object
#  9   wd          999 non-null    int64
#  10  wdQcflg     999 non-null    object
#  11  hm          999 non-null    int64
#  12  hmQcflg     999 non-null    object
#  13  pv          999 non-null    float64
#  14  td          999 non-null    float64
#  15  pa          999 non-null    float64
#  16  paQcflg     999 non-null    object
#  17  ps          999 non-null    float64
#  18  psQcflg     999 non-null    object
# ...

# %%
a.to_csv('data/AsosHourlyInfoService.csv', index=False, encoding='cp949')
